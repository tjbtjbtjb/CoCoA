# %%
from cocoa import covid19 as cc

# %%
p=cc.Parser()

# %%
z1=p.getStats(which='deaths',country=['France','Spain','Mexico'],type='Diff',option='nonneg')
z2=p.getStats(which='deaths',country=['France','Spain','Mexico'],type='Diff')

# %%
import matplotlib.pyplot as plt
plt.plot(z1)
plt.plot(z2)

# %%
from cocoa import world as cw

# %%
w=cw.WorldInfo()

# %%
asia=w.getAsiaCountries()

# %%
print(asia)
# Out:
# ['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China', 'Cyprus', 'Georgia', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Korea, South', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Nepal', 'Oman', 'Pakistan', 'Philippines', 'Qatar', 'Saudi Arabia', 'Singapore', 'Sri Lanka', 'Syria', 'Tajikistan', 'Thailand', 'Timor-Leste', 'Turkey', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen']

# %%
z3=p.getStats(which='confirmed',country=asia,type='Diff')

# %%
p.which_data_list
# Out:
# ['deaths', 'confirmed', 'recovered']

# %%
plt.plot(z3)
plt.legend(asia)

# %%
asia
# Out:
# ['Afghanistan',
#  'Armenia',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Bhutan',
#  'Brunei',
#  'Cambodia',
#  'China',
#  'Cyprus',
#  'Georgia',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Israel',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Korea, South',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Lebanon',
#  'Malaysia',
#  'Maldives',
#  'Mongolia',
#  'Nepal',
#  'Oman',
#  'Pakistan',
#  'Philippines',
#  'Qatar',
#  'Saudi Arabia',
#  'Singapore',
#  'Sri Lanka',
#  'Syria',
#  'Tajikistan',
#  'Thailand',
#  'Timor-Leste',
#  'Turkey',
#  'United Arab Emirates',
#  'Uzbekistan',
#  'Vietnam',
#  'Yemen']
