# %%
import sys
sys.path.insert(1, '..')
import cocoa.cocoa as cc

# %%
import importlib
importlib.reload(cc)
# Out:
# JHU aka Johns Hopkins database selected ...
# Available keys words for  jhu  are :  ['deaths', 'confirmed', 'recovered']
# Last date data  10/14/20
# <module 'cocoa.cocoa' from '../cocoa/cocoa.py'>

# %%
cc.get(whom='owid',where='Spain',which='new_cases_per_million')
# Out:
# OWID aka "Our World in Data" database selected ...
# ../cocoa/geo.py:171: UserWarning: Caution. More than one country match the key "Curacao" : ['Netherlands, ', 'Curaçao, '], using first one.
#
#   ', using first one.\n')
# ../cocoa/geo.py:171: UserWarning: Caution. More than one country match the key "Iran" : ['Iran, Islamic Republic of, ', 'Albania, ', 'Slovenia, ', 'Venezuela, Bolivarian Republic of, ', 'Bhutan, ', 'Philippines, ', 'Madagascar, '], using first one.
#
#   ', using first one.\n')
# Available keys words for  owid  are :  ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# Last date data  10/15/20
# -W _db owid
# ../cocoa/cocoa.py:184: UserWarning: whom keyword not yet implemented. Using default
#   warnings.warn('whom keyword not yet implemented. Using default')
# ../cocoa/cocoa.py:102: UserWarning: cocoa.setbase() function not yet fully implemented
#   warnings.warn("cocoa.setbase() function not yet fully implemented")
# OWID aka "Our World in Data" database selected ...
# Available keys words for  owid  are :  ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# Last date data  10/15/20
#           date  new_tests_per_thousand  cumul  diff
# 0   2019-12-31                     NaN  0.000   0.0
# 1   2020-01-01                     NaN  0.000   NaN
# 2   2020-01-02                     NaN  0.000   NaN
# 3   2020-01-03                     NaN  0.000   NaN
# 4   2020-01-04                     NaN  0.000   NaN
# ..         ...                     ...    ...   ...
# 285 2020-10-11                     NaN  2.087   NaN
# 286 2020-10-12                     NaN  2.087   NaN
# 287 2020-10-13                     NaN  2.087   NaN
# 288 2020-10-14                     NaN  2.087   NaN
# 289 2020-10-15                     NaN  2.087   NaN
#
# [290 rows x 4 columns]

# %%
cc.map(whom='owid',where='European Union',which='new_cases_per_million')
# Out:
# OWID aka "Our World in Data" database selected ...
# ../cocoa/geo.py:171: UserWarning: Caution. More than one country match the key "Curacao" : ['Netherlands, ', 'Curaçao, '], using first one.
#
#   ', using first one.\n')
# ../cocoa/geo.py:171: UserWarning: Caution. More than one country match the key "Iran" : ['Iran, Islamic Republic of, ', 'Albania, ', 'Slovenia, ', 'Venezuela, Bolivarian Republic of, ', 'Bhutan, ', 'Philippines, ', 'Madagascar, '], using first one.
#
#   ', using first one.\n')
# Available keys words for  owid  are :  ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# Last date data  10/15/20
# -W _db owid
# ../cocoa/cocoa.py:184: UserWarning: whom keyword not yet implemented. Using default
#   warnings.warn('whom keyword not yet implemented. Using default')
# ../cocoa/cocoa.py:102: UserWarning: cocoa.setbase() function not yet fully implemented
#   warnings.warn("cocoa.setbase() function not yet fully implemented")
# OWID aka "Our World in Data" database selected ...
# Available keys words for  owid  are :  ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# Last date data  10/15/20
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1228">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a1c7eece-bf59-4970-a478-82adf620e7af" data-root-id="1202"></div>

# %%
# Out:
# -W _db jhu
# OWID aka "Our World in Data" database selected ...
# Available keys words for  owid  are :  ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# Last date data  10/15/20
# ---------------------------------------------------------------
# KeyError                      Traceback (most recent call last)
# <ipython-input-7-bcd3bea174ee> in <module>
# ----> 1 cc.get(whom='owid',where='Spain',which='new_cases',what='diff')
#
# ~/Programs/Python/CoCoA/cocoa/cocoa.py in get(**kwargs)
#     194         which=listwhich()[0]
#     195     elif which not in setwhom(whom):
# --> 196         raise CocoaKeyError('Which option '+which+' not supported. '
#     197                             'See listwhich() for list.')
#     198     return _db.get_stats(which=which,type=what,location=where,output=output)
#
# ~/Programs/Python/CoCoA/cocoa/covid19.py in get_stats(self, **kwargs)
#     297
#     298         currentout = np.array(tuple(dict(
# --> 299             (c, (self.get_current_days()[kwargs['which']][c])) for c in clist).values()))
#     300         cumulout = np.array(tuple(dict(
#     301             (c, (self.get_cumul_days()[kwargs['which']][c])) for c in clist).values()))
#
# ~/Programs/Python/CoCoA/cocoa/covid19.py in <genexpr>(.0)
#     297
#     298         currentout = np.array(tuple(dict(
# --> 299             (c, (self.get_current_days()[kwargs['which']][c])) for c in clist).values()))
#     300         cumulout = np.array(tuple(dict(
#     301             (c, (self.get_cumul_days()[kwargs['which']][c])) for c in clist).values()))
#
# KeyError: 'new_cases'

# %%
cc.plot(where=['France','Italy'],which='deaths',what='Cumul') # Caution, Cumul will become cumul (lower case)

# %%
cc.listwhat()
# Out:
# ['Cumul', 'Diff', 'cumul', 'daily', 'weekly']

# %%
cc.listwhom()
# Out:
# ['jhu', 'spf', 'opencovid19']

# %%
cc.listwhich()
# Out:
# ['deaths', 'confirmed', 'recovered']

# %%
cc.setwhom('jhu')
# Out:
# ../cocoa/cocoa.py:99: UserWarning: cocoa.setbase() function not yet fully implemented
#   warnings.warn("cocoa.setbase() function not yet fully implemented")
# JHU aka Johns Hopkins database selected ...
# Available keys words for  jhu  are :  ['deaths', 'confirmed', 'recovered']
# Last date data  10/14/20
# ['deaths', 'confirmed', 'recovered']

# %%
cc.map(where='European Union',which='recovered')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1340">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f43b8426-876f-490f-826d-276d3327c437" data-root-id="1314"></div>

# %%
import importlib
importlib.reload(cc)
# Out:
# JHU aka Johns Hopkins database selected ...
# Available keys words for  jhu  are :  ['deaths', 'confirmed', 'recovered']
# Last date data  10/14/20
# <module 'cocoa.cocoa' from '../cocoa/cocoa.py'>

# %%
cc.setwhom('owid')
# Out:
# OWID aka "Our World in Data" database selected ...
# Available keys words for  owid  are :  ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# Last date data  10/15/20
# ['total_cases',
#  'new_cases',
#  'total_deaths',
#  'new_deaths',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'total_tests',
#  'new_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'stringency_index']

# %%
cc.listwhich('owid')
# Out:
# OWID aka "Our World in Data" database selected ...
# Available keys words for  owid  are :  ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# Last date data  10/15/20
# ['total_cases',
#  'new_cases',
#  'total_deaths',
#  'new_deaths',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'total_tests',
#  'new_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'stringency_index']

# %%
import importlib
importlib.reload(cc)
# Out:
# JHU aka Johns Hopkins database selected ...
# Available keys words for  jhu  are :  ['deaths', 'confirmed', 'recovered']
# Last date data  10/14/20
# <module 'cocoa.cocoa' from '../cocoa/cocoa.py'>

# %%
cc.

# %%
cc.map(whom='owid',where='European Union',which='new_deaths_per_million')
# Out:
# owid
# OWID aka "Our World in Data" database selected ...
# Available keys words for  owid  are :  ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# Last date data  10/15/20
# ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# -------> <cocoa.covid19.DataBase object at 0x120959b50> ['jhu', 'owid', 'spf', 'opencovid19']
# OWID aka "Our World in Data" database selected ...
# Available keys words for  owid  are :  ['total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 'new_deaths_per_million', 'total_tests', 'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'stringency_index']
# Last date data  10/15/20
# ---------------------------------------------------------------
# KeyError                      Traceback (most recent call last)
# <ipython-input-102-454ed62bfaeb> in <module>
# ----> 1 cc.map(whom='owid',where='European Union',which='new_deaths_per_million')
#
# ~/Programs/Python/CoCoA/cocoa/cocoa.py in map(**kwargs)
#     300     """
#     301     wlist=copy(kwargs.get('where',None))
# --> 302     p=get(**kwargs)
#     303
#     304     which=kwargs.get('which',None)
#
# ~/Programs/Python/CoCoA/cocoa/cocoa.py in get(**kwargs)
#     201                             'See listwhich() for list.')
#     202
# --> 203     return _db.get_stats(which=which,type=what,location=where)
#     204
#     205 # ----------------------------------------------------------------------
#
# ~/Programs/Python/CoCoA/cocoa/covid19.py in get_stats(self, **kwargs)
#     297
#     298         currentout = np.array(tuple(dict(
# --> 299             (c, (self.get_current_days()[kwargs['which']][c])) for c in clist).values()))
#     300         cumulout = np.array(tuple(dict(
#     301             (c, (self.get_cumul_days()[kwargs['which']][c])) for c in clist).values()))
#
# ~/Programs/Python/CoCoA/cocoa/covid19.py in <genexpr>(.0)
#     297
#     298         currentout = np.array(tuple(dict(
# --> 299             (c, (self.get_current_days()[kwargs['which']][c])) for c in clist).values()))
#     300         cumulout = np.array(tuple(dict(
#     301             (c, (self.get_cumul_days()[kwargs['which']][c])) for c in clist).values()))
#
# KeyError: 'new_deaths_per_million'

# %%
# Out:
# 50.2
